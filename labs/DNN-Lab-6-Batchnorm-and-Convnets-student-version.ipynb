# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# This exercise covers two aspects:
# * In tasks 1-6 you will implement mechanisms that allow training deeper models. After doing each of the tasks you can look at the plots and check how your changes impact gradients of network layers.
# * In task 7 you will implement a convnet using [conv2d](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html) and try to reach 99% accuracy on MNIST.
#
# For this notebook, running on CPU is sufficient: tasks 1–5. run under a minute, 6. under two minutes, and 7. up to 5 minutes.
#
# Tasks:
# 1. Check that the given implementation reaches 95% test accuracy for
#    the architecture `input-64-64-10` in 8 epochs.
# 2. Modify `Linear.reset_parameters()` to improve initialization and
#    check that the network learns much faster and reaches over 97% test accuracy.
#    A good basic initialization scheme is so-called *Glorot initialization*.
#    For a linear layer with $n_{in}$ and  $n_{out}$ input and output features,
#    it samples each weight from a normal distribution with $0$ mean and a standard deviation of $\sqrt{\frac{2}{n_{in}+n_{out}}}$.
#    Check how that changes the distribution of gradients at the first epoch.
# 3. Check, that with proper initialization we can train the architecture
#    `input-64-64-64-64-64-64-64-10` (seven hidden layers of `64`), for e.g. 3 epochs,
#    while with the original, bad initialization, it does not even get off the ground.
# 4. Implement Dropout as a PyTorch module (without using torch.nn.Dropout).
#    Use `p=0.25` as the zeroing probability.
#    Use Dropout after activations of each layer, except the last.
# 5. Check that with 10 hidden layers (64 units each), even with proper initialization,
#    but with dropout added, the network has a hard time to start learning.
# 6. Implement batch normalization (without using torch.nn.BatchNorm).
#     * compute batch mean and variance
#     * add new variables beta and gamma
#     * check that the network learns even for 10 hidden layers.
#     * check how gradients change in comparison to network without batch norm.
#
#    In pseudo-code:
#     ```
# 		if training:
# 		    var, mean = torch.var_mean(x, dim=/batch/)
# 		    update running_mean, running_var
# 		else:
# 			mean, var = running_mean, running_var
# 		x = (x - mean) / sqrt(var + eps)
# 		return x * gamma + beta
#     ```
#
# 7. Design and implement a simple convolutional network and achieve 99% test accuracy (in up to 10 epochs, 5 should be enough). The architecture is up to you, but even a few convolutional layers should be enough.
# You may use `torch.nn.Conv2d, BatchNorm2d, MaxPool2d, ReLU, Dropout2d, Linear, Flatten, BatchNorm1d`.
# Don't make it too generic, just try a few fixed layers.

# %%
import math
import sys

import numpy as np
import PIL.Image
import plotly.express as px
import plotly.graph_objects as go
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from plotly.subplots import make_subplots
from torch import Tensor
from torch.nn import init

if 'google.colab' in sys.modules:
    from google.colab import output
    output.enable_custom_widget_manager()

# %%
# @title Visualize gradients

class GradientVisualizer:
    def __init__(self, net: nn.Module, num_epochs: int) -> None:
        self.num_epochs = num_epochs
        self.linear_layers = self.get_linear_layers(net)

        self.grad_to_weight_fig = None
        self.grads_in_layers_fig = None
        self.grads_at_epochs_fig = None
        self.init_figures()

    @staticmethod
    def get_linear_layers(net):
        linear_layers = []
        for field in net.modules():
            if isinstance(field, nn.Linear | Linear):
                linear_layers.append(field)
        assert linear_layers, "No linear layers found. Forgot to use Sequential or ModuleList?"
        return linear_layers

    def get_epochs_for_one_layer(self):
        """
        We want to show gradient distributions from up to 7 selected epochs
        for one linear layer.
        """
        if self.num_epochs < 7:
            return list(range(self.num_epochs))
        else:
            return torch.linspace(0, self.num_epochs - 1, 7).int().tolist()

    def get_three_epochs(self):
        """
        We want to show gradients distributions from all layers at each of
        three epochs: first, middle and last.
        """
        return [0, self.num_epochs // 2, self.num_epochs - 1]

    def rgb_to_rgba(self, rgb_color, epoch):
        """
        Value of epoch parameter determines how transparent color should be
        in comparison to others.
        Colors for earlier epochs should be more transparent/less visible.
        """
        return f'rgba{rgb_color[3:-1]},{0.6 * (epoch + 1) / self.num_epochs + 0.15})'

    def init_figures(self):
        # Initialize figure with gradient to weight ratio plot
        fig = go.Figure()
        fig.update_layout(
            title='Gradient stddev to weight stddev ratio', title_x=0.5,
            xaxis_title='Epoch',
            yaxis_title='Gradient to weight ratio (log scale)',
            height=400, width=1500, margin=dict(b=10, t=60)
        )
        fig.update_yaxes(type='log')
        for i in range(len(self.linear_layers)):
            fig.add_trace(go.Scatter(
                x=[], y=[],
                mode='lines+markers', name=f'Linear layer {i}'
            ))

        self.grad_to_weight_fig = go.FigureWidget(fig)
        display(self.grad_to_weight_fig)

        # Initialize figure visualizing gradient distributions in layers
        chosen_layers = [0, len(self.linear_layers) // 2, len(self.linear_layers) - 1]
        num_rows = (len(chosen_layers) - 1) // 3 + 1
        fig = make_subplots(
            rows=num_rows, cols=3,
            subplot_titles=[f'Linear layer {i}' for i in chosen_layers],
            vertical_spacing=0.2 / num_rows
        )
        fig.update_layout(
            title='Gradient distributions by epoch (for three chosen layers)', title_x=0.5,
            height=num_rows * 400, width=1500, margin=dict(b=10, t=60)
        )

        colors, _ = px.colors.convert_colors_to_same_type(2 * px.colors.qualitative.Plotly)
        for i, layer_num in enumerate(chosen_layers):
            row = i // 3 + 1
            col = i % 3 + 1
            fig.update_xaxes(
                title_text='Gradient value', range=(-0.1, 0.1), row=row, col=col
            )
            fig.update_yaxes(
                title_text='Density (log scale)', type='log', row=row, col=col
            )

            # Create empty traces and update them later with actual gradient distributions.
            # Unfortunately, we cannot add new traces dynamically because Colab has problem
            # with widgets from plotly (traces added dynamically are rendered twice).
            for epoch in self.get_epochs_for_one_layer():
                fig.add_trace(
                    go.Scatter(
                        mode='lines', name=f'Epoch {epoch + 1}',
                        line=dict(color=self.rgb_to_rgba(colors[layer_num], epoch)),
                        legendgroup=layer_num
                    ),
                    row=row, col=col
                )

        self.grads_in_layers_fig = go.FigureWidget(fig)
        display(self.grads_in_layers_fig)

        # Initialize figure comparing gradient distributions between layers at the
        # first, middle and last epoch
        selected_epochs_indices = self.get_three_epochs()
        fig = make_subplots(
            rows=1, cols=3,
            subplot_titles=[f'Epoch {epoch + 1}' for epoch in selected_epochs_indices]
        )
        fig.update_layout(
            title='Gradient distributions by layers (for three chosen epochs)', title_x=0.5,
            height=400, width=1500, margin=dict(b=10, t=60)
        )

        for col, epoch in enumerate(selected_epochs_indices, 1):
            fig.update_yaxes(title_text='Density (log scale)', type='log', row=1, col=col)
            fig.update_xaxes(
                title_text='Gradient value',
                range=(-0.05, 0.05) if epoch != 0 else (-1, 1),
                row=1, col=col
            )

            # Create empty traces and update them later with actual gradient distributions.
            for layer_num in range(len(self.linear_layers)):
                fig.append_trace(
                    go.Scatter(
                        mode='lines', name=f'Linear layer {layer_num}',
                        line=dict(color=colors[layer_num]), showlegend=(col == 1)
                    ),
                    row=1, col=col
                )

        self.grads_at_epochs_fig = go.FigureWidget(fig)
        display(self.grads_at_epochs_fig)

    def visualize_gradients(self, lr, epoch, batch_idx):
        # It is enough to use gradients calculated for the first batch.
        if batch_idx != 0:
            return

        epoch_grads = []
        epoch_grad_to_weight_ratios = []
        for layer in self.linear_layers:
            epoch_grads.append(layer.weight.grad.flatten().detach())
            epoch_grad_to_weight_ratios.append(
                (lr * layer.weight.grad.std() / layer.weight.std()).item()
            )

        # Update figure with gradient to weight ratio plot
        assert self.grad_to_weight_fig is not None
        for i, grad_to_weight_ratio in enumerate(epoch_grad_to_weight_ratios):
            x = self.grad_to_weight_fig.data[i].x
            next_x_val = x[-1] + 1 if x else 1
            self.grad_to_weight_fig.data[i].x += (next_x_val, )
            self.grad_to_weight_fig.data[i].y += (grad_to_weight_ratio, )

        # Update figure visualizing gradient distributions in layers
        assert self.grads_in_layers_fig is not None
        chosen_layers = [0, len(self.linear_layers) // 2, len(self.linear_layers) - 1]
        selected_epochs = self.get_epochs_for_one_layer()
        if epoch in selected_epochs:
            epoch_idx = selected_epochs.index(epoch)
            for layer_num, layer_grad in enumerate(epoch_grads):
                try:
                    layer_id = chosen_layers.index(layer_num)
                except ValueError:
                    continue
                trace_idx = layer_id * len(selected_epochs) + epoch_idx
                try:
                    hy, hx = torch.histogram(layer_grad, bins=50, density=True)
                except RuntimeError:
                    continue
                hy = hy / max(hy) + 0.001
                self.grads_in_layers_fig.data[trace_idx].x = hx[:-1].tolist()
                self.grads_in_layers_fig.data[trace_idx].y = hy.tolist()


        # Update figure visualizing gradient distributions at epochs
        assert self.grads_at_epochs_fig is not None
        selected_epochs = self.get_three_epochs()
        if epoch in selected_epochs:
            epoch_idx = selected_epochs.index(epoch)
            for layer_num, layer_grad in enumerate(epoch_grads):
                trace_idx = epoch_idx * len(self.linear_layers) + layer_num
                try:
                    hy, hx = torch.histogram(layer_grad, bins=50, density=True)
                except RuntimeError:
                    continue
                hy = hy / max(hy) + 0.001
                self.grads_at_epochs_fig.data[trace_idx].x = hx[:-1].tolist()
                self.grads_at_epochs_fig.data[trace_idx].y = hy.tolist()

# %%
class Linear(nn.Module):
    def __init__(self, in_features: int, out_features: int, glorot_init: bool) -> None:
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(Tensor(out_features, in_features))
        self.bias = nn.Parameter(Tensor(out_features))
        self.glorot_init = glorot_init
        self.reset_parameters()

    def reset_parameters(self) -> None:
        if self.glorot_init:
            std = np.sqrt(2 / (self.in_features + self.out_features))
            self.weight.data.normal_(mean=0, std=std)
        else:
            self.weight.data.normal_(mean=0, std=0.25)
        init.zeros_(self.bias)

    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (*B, in_features)
        Output: shape (*B, out_features)
        """
        r = x.matmul(self.weight.T)
        r += self.bias
        return r


class Net(nn.Module):
    def __init__(self, glorot_init: bool = False) -> None:
        super().__init__()
        # # org
        # self.fc1 = Linear(784, 64, glorot_init=glorot_init)
        # self.fc2 = Linear(64, 64, glorot_init=glorot_init)
        # self.fc3 = Linear(64, 10, glorot_init=glorot_init)

        self.fc1 = Linear(784, 64, glorot_init=glorot_init)
        self.fc2 = Linear(64, 64, glorot_init=glorot_init)
        self.fc3 = Linear(64, 64, glorot_init=glorot_init)
        self.fc4 = Linear(64, 64, glorot_init=glorot_init)
        self.fc5 = Linear(64, 64, glorot_init=glorot_init)
        self.fc6 = Linear(64, 64, glorot_init=glorot_init)
        self.fc7 = Linear(64, 64, glorot_init=glorot_init)
        self.fc8 = Linear(64, 64, glorot_init=glorot_init)
        self.fc9 = Linear(64, 10, glorot_init=glorot_init)

        # self.fc = [Linear(784, 64, glorot_init=glorot_init)] + [Linear(64, 64, glorot_init=glorot_init)]*7 + [Linear(64, 10, glorot_init=glorot_init)]


    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (B, H=28, W=28)
        Output: shape (B, num_classes=10)
        """
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = F.relu(self.fc7(x))
        x = F.relu(self.fc8(x))
        x = self.fc9(x)

        # x = self.fc3(x)

        # for layer in self.fc[:-1]:
        #     x = F.relu(layer(x))
        # x = self.fc[-1](x)
        return x

# %%
class MnistTrainer:
    def __init__(self, batch_size: int = 128) -> None:
        transform = transforms.Compose([transforms.ToTensor()])
        self.trainset = torchvision.datasets.MNIST(
            root='./data', download=True, train=True, transform=transform
        )
        self.trainloader = torch.utils.data.DataLoader(
            self.trainset, batch_size=batch_size, shuffle=True, num_workers=2
        )
        self.testset = torchvision.datasets.MNIST(
            root='./data', train=False, download=True, transform=transform
        )
        self.testloader = torch.utils.data.DataLoader(
            self.testset, batch_size=1000, shuffle=False, num_workers=2
        )

    def train(
        self,
        net: nn.Module,
        gradient_visualizer: GradientVisualizer | None = None,
        epochs: int = 20,
        lr: float = 0.05,
        momentum: float = 0.9
    ) -> None:
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)
        log_freq = 100

        for epoch in range(epochs):
            net.train()
            running_loss = 0.0
            for i, data in enumerate(self.trainloader):
                inputs, labels = data
                optimizer.zero_grad()

                outputs = net(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                if gradient_visualizer is not None:
                    gradient_visualizer.visualize_gradients(lr, epoch, i)
                optimizer.step()

                running_loss += loss.item()
                if i % log_freq == log_freq - 1:
                    running_loss /= log_freq
                    print(f"epoch {epoch + 1:>5}, batch {i + 1:>5}, loss {running_loss:.3f}")
                    running_loss = 0.0
            self.test(net)

    def test(self, net: nn.Module) -> list[float]:
        net.eval()
        correct = 0
        total = 0
        all_gt_logits = []
        with torch.no_grad():
            for data in self.testloader:
                images, labels = data
                outputs = net(images)
                gt_logits = torch.gather(outputs, dim=1, index=labels.unsqueeze(-1))
                all_gt_logits.extend(float(logit.item()) for logit in gt_logits)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print(f"Accuracy of the network on the {total} test images: {correct / total:.2%}")
        return all_gt_logits

    def show_worst_misclassified(self, net: nn.Module, k: int = 10) -> None:
        all_gt_logits = self.test(net)
        _, indices = torch.topk(-torch.tensor(all_gt_logits), k)
        imgs = []
        labels = []
        for i in indices:
            img, label = self.testset[int(i.item())]
            imgs.append(img)
            labels.append(label)
        image = PIL.Image.fromarray(
            torch.cat(imgs, dim=-1).mul(255).to(torch.uint8).permute(1, 2, 0).numpy().squeeze()
        )
        display(image.resize((5 * image.width, 5 * image.height), PIL.Image.Resampling.NEAREST))
        print(labels)

# %%
epochs = 8

net = Net(glorot_init=True)
gradient_visualizer = GradientVisualizer(net, epochs)
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Linear layer 0',
#               'type': 'scatter',
#               'uid': 'e532bd94-0750-46d5-993b-2c9e8bb2f10a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 1',
#               'type': 'scatter',
#               'uid': '0098b1f5-d866-48a2-a580-cff3849adce4',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 2',
#               'type': 'scatter',
#               'uid': '00689d11-fe71-4b8b-8193-224ba7fa23e8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 3',
#               'type': 'scatter',
#               'uid': '6e491e7a-4a9a-4723-a091-78b23f6c025d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 4',
#               'type': 'scatter',
#               'uid': '7494e01a-ab02-4817-a827-b6b0d2bc1c3a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 5',
#               'type': 'scatter',
#               'uid': '158564fd-5cc9-472e-9d90-c8aa787bf25d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 6',
#               'type': 'scatter',
#               'uid': '75b9d44e-a50f-4198-bb58-98ce5bc9f551',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 7',
#               'type': 'scatter',
#               'uid': '825e71cf-bc78-4849-8ec3-e0ca000c639f',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 8',
#               'type': 'scatter',
#               'uid': '5ada210d-d227-4e44-ac89-0c7f9cb60ad6',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient stddev to weight stddev ratio', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Epoch'}},
#                'yaxis': {'title': {'text': 'Gradient to weight ratio (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.22499999999999998)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '086a3e55-be9e-431e-b18e-56abf1f8c93d',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.3)'},
#               'mode': 'lines',
#               'name': 'Epoch 2',
#               'type': 'scatter',
#               'uid': 'b41b74a8-e88b-42f5-a80f-5f674a1c755d',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.375)'},
#               'mode': 'lines',
#               'name': 'Epoch 3',
#               'type': 'scatter',
#               'uid': 'ee8150ce-ec03-40dc-86d5-06619f93aac8',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '6e9523c7-d412-42cf-a5ac-06e9496585bf',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.525)'},
#               'mode': 'lines',
#               'name': 'Epoch 5',
#               'type': 'scatter',
#               'uid': '77d6c55d-3f13-43a8-8399-5b79fa746494',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.6)'},
#               'mode': 'lines',
#               'name': 'Epoch 6',
#               'type': 'scatter',
#               'uid': 'bceb3b8f-7edd-4b11-a0b1-da4d4db2af3f',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 8',
#               'type': 'scatter',
#               'uid': '76ee8231-db04-4425-ae03-363533403bbc',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.22499999999999998)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'fb9f5faa-25fc-4cf6-983b-17d427732d8c',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.3)'},
#               'mode': 'lines',
#               'name': 'Epoch 2',
#               'type': 'scatter',
#               'uid': '83f07078-b8e5-46d2-94d9-4c33ff9d8f06',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.375)'},
#               'mode': 'lines',
#               'name': 'Epoch 3',
#               'type': 'scatter',
#               'uid': '94a6837d-70a8-4839-b23e-563e68a78192',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '29fd643e-827a-45e7-8663-9cf3e11847da',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.525)'},
#               'mode': 'lines',
#               'name': 'Epoch 5',
#               'type': 'scatter',
#               'uid': 'f97511cd-b2fb-4e60-a295-573e45a8b525',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.6)'},
#               'mode': 'lines',
#               'name': 'Epoch 6',
#               'type': 'scatter',
#               'uid': '955177d6-f1eb-4829-af0a-a059e43e8d6d',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 8',
#               'type': 'scatter',
#               'uid': 'e3bfe21b-9959-49f5-808f-8c90dd753a21',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.22499999999999998)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'a40a3ef0-3318-4720-bd35-cb5c0d0c98bd',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.3)'},
#               'mode': 'lines',
#               'name': 'Epoch 2',
#               'type': 'scatter',
#               'uid': '5bfbbe5b-c885-45d4-b9f8-822db66c49eb',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.375)'},
#               'mode': 'lines',
#               'name': 'Epoch 3',
#               'type': 'scatter',
#               'uid': '841b7f09-6312-427d-b4d4-73679fff538d',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '4f6efd26-cfe4-4622-9ebf-9d51e558a32d',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.525)'},
#               'mode': 'lines',
#               'name': 'Epoch 5',
#               'type': 'scatter',
#               'uid': '81596ccb-ea58-4ed9-bcbd-c043e821b617',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.6)'},
#               'mode': 'lines',
#               'name': 'Epoch 6',
#               'type': 'scatter',
#               'uid': 'd7535944-b408-440e-9148-c3b068bdf46c',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 8',
#               'type': 'scatter',
#               'uid': 'cedcb89e-ba6b-46c8-8a81-d393481ece44',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 0',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 4',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 8',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient distributions by epoch (for three chosen layers)', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-0.1, 0.1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '834d8fd3-ddc7-4c07-9412-868e38552b87',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '50f92ad4-e454-46d3-9298-0082b480e075',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '042e8dd7-63ca-4777-b3e7-96a9deb1cd2d',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(171, 99, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 3',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a63952f1-e480-45ac-9f15-ef4209f04583',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(255, 161, 90)'},
#               'mode': 'lines',
#               'name': 'Linear layer 4',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'aae94d1f-74bb-46c9-b0c0-001dea8df2a8',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(25, 211, 243)'},
#               'mode': 'lines',
#               'name': 'Linear layer 5',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '775dfc92-a3bd-43f6-bbea-840f9ded6400',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(255, 102, 146)'},
#               'mode': 'lines',
#               'name': 'Linear layer 6',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f5d90640-d9e3-4be1-b3df-767fe79e5d97',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(182, 232, 128)'},
#               'mode': 'lines',
#               'name': 'Linear layer 7',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3aa5b915-375a-4578-886b-021257ca9edd',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(255, 151, 255)'},
#               'mode': 'lines',
#               'name': 'Linear layer 8',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c1152509-fac2-4d3e-92dd-3ee1e103d8ea',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '836d9baf-b92d-4fba-8b53-3867e59265d1',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '903deeae-32e0-4aa9-a823-e5ea820c1223',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3a92e073-8eab-430e-a908-162aca7bf0ff',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(171, 99, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9ad35d71-23d9-4d40-bb35-7faa5a730cd8',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(255, 161, 90)'},
#               'mode': 'lines',
#               'name': 'Linear layer 4',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '62b543a8-21a2-4c3d-ba94-3fbb20b314d1',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(25, 211, 243)'},
#               'mode': 'lines',
#               'name': 'Linear layer 5',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3841f4ef-d7eb-43f8-9842-e464cb2e2dde',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(255, 102, 146)'},
#               'mode': 'lines',
#               'name': 'Linear layer 6',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b23b05ed-1729-4916-99fe-376003a3bf31',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(182, 232, 128)'},
#               'mode': 'lines',
#               'name': 'Linear layer 7',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '80b3150e-cd4e-487e-a192-dae59f909f62',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(255, 151, 255)'},
#               'mode': 'lines',
#               'name': 'Linear layer 8',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '75cd23cd-9fdf-46ef-8e8b-baf5e572ed1a',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'dd96fd8a-a098-43a1-87f2-b50904927681',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '835736fe-6aa2-46f4-9453-b16eb0f1c38e',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e1399366-0987-4e79-8b50-f46cb73a8ce1',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(171, 99, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fe364b17-d515-45b4-ae63-6006dfd0bf91',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(255, 161, 90)'},
#               'mode': 'lines',
#               'name': 'Linear layer 4',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8d903634-ac7a-4ac3-b408-37c69e815aa3',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(25, 211, 243)'},
#               'mode': 'lines',
#               'name': 'Linear layer 5',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f04ff258-f247-4878-9319-2399bfc11a04',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(255, 102, 146)'},
#               'mode': 'lines',
#               'name': 'Linear layer 6',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8f82d1dd-6154-47ca-8e8c-0f84e29920d6',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(182, 232, 128)'},
#               'mode': 'lines',
#               'name': 'Linear layer 7',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9a4295c8-c109-48e2-a908-fa5b9badfd41',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(255, 151, 255)'},
#               'mode': 'lines',
#               'name': 'Linear layer 8',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'dcf5451e-19c3-4aa8-a52e-e6df3f3a9d6a',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 1',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 5',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 8',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient distributions by layers (for three chosen epochs)', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-1, 1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })

# %%
trainer = MnistTrainer(batch_size=128)
trainer.train(net, gradient_visualizer, epochs=epochs)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 59.2MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.63MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.0MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.85MB/s]
# epoch     1, batch   100, loss 1.487
# epoch     1, batch   200, loss 0.456
# epoch     1, batch   300, loss 0.305
# epoch     1, batch   400, loss 0.256
# Accuracy of the network on the 10000 test images: 94.13%
# epoch     2, batch   100, loss 0.186
# epoch     2, batch   200, loss 0.194
# epoch     2, batch   300, loss 0.180
# epoch     2, batch   400, loss 0.166
# Accuracy of the network on the 10000 test images: 95.63%
# epoch     3, batch   100, loss 0.135
# epoch     3, batch   200, loss 0.138
# epoch     3, batch   300, loss 0.136
# epoch     3, batch   400, loss 0.143
# Accuracy of the network on the 10000 test images: 96.17%
# epoch     4, batch   100, loss 0.118
# epoch     4, batch   200, loss 0.113
# epoch     4, batch   300, loss 0.104
# epoch     4, batch   400, loss 0.110
# Accuracy of the network on the 10000 test images: 96.84%
# epoch     5, batch   100, loss 0.090
# epoch     5, batch   200, loss 0.099
# epoch     5, batch   300, loss 0.096
# epoch     5, batch   400, loss 0.101
# Accuracy of the network on the 10000 test images: 96.68%
# epoch     6, batch   100, loss 0.074
# epoch     6, batch   200, loss 0.082
# epoch     6, batch   300, loss 0.079
# epoch     6, batch   400, loss 0.084
# Accuracy of the network on the 10000 test images: 97.06%
# epoch     7, batch   100, loss 0.071
# epoch     7, batch   200, loss 0.067
# epoch     7, batch   300, loss 0.072
# epoch     7, batch   400, loss 0.081
# Accuracy of the network on the 10000 test images: 97.03%
# epoch     8, batch   100, loss 0.061
# epoch     8, batch   200, loss 0.065
# epoch     8, batch   300, loss 0.061
# epoch     8, batch   400, loss 0.063
# Accuracy of the network on the 10000 test images: 97.15%

# %% [markdown]
# # Task 3

# %%
epochs = 3
net = Net(glorot_init=False)

# %%
trainer = MnistTrainer(batch_size=128)
trainer.train(net, None, epochs=3)
# Out:
# epoch     1, batch   100, loss nan
# epoch     1, batch   200, loss nan
# epoch     1, batch   300, loss nan
# epoch     1, batch   400, loss nan
# Accuracy of the network on the 10000 test images: 9.80%
# epoch     2, batch   100, loss nan
# epoch     2, batch   200, loss nan
# epoch     2, batch   300, loss nan
# epoch     2, batch   400, loss nan
# Accuracy of the network on the 10000 test images: 9.80%
# epoch     3, batch   100, loss nan
# epoch     3, batch   200, loss nan
# epoch     3, batch   300, loss nan
# epoch     3, batch   400, loss nan
# Accuracy of the network on the 10000 test images: 9.80%

# %%
epochs = 3
net = Net(glorot_init=True)
trainer = MnistTrainer(batch_size=128)
trainer.train(net, None, epochs=3)
# Out:
# epoch     1, batch   100, loss 2.130
# epoch     1, batch   200, loss 1.128
# epoch     1, batch   300, loss 0.572
# epoch     1, batch   400, loss 0.411
# Accuracy of the network on the 10000 test images: 89.69%
# epoch     2, batch   100, loss 0.288
# epoch     2, batch   200, loss 0.259
# epoch     2, batch   300, loss 0.236
# epoch     2, batch   400, loss 0.214
# Accuracy of the network on the 10000 test images: 94.89%
# epoch     3, batch   100, loss 0.181
# epoch     3, batch   200, loss 0.193
# epoch     3, batch   300, loss 0.178
# epoch     3, batch   400, loss 0.166
# Accuracy of the network on the 10000 test images: 95.67%

# %% [markdown]
# # Zadanie 4

# %%
class MujDropout(nn.Module):
    def __init__(self, p: float = 0.25) -> None:
        super().__init__()
        self.p = p
    def forward(self, input: Tensor) -> Tensor:
        input = input * (1/(1-self.p))
        mask = torch.rand_like(input) < self.p
        input[mask] = 0
        return input

# %%
class Linear(nn.Module):
    def __init__(self, in_features: int, out_features: int, glorot_init: bool) -> None:
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(Tensor(out_features, in_features))
        self.bias = nn.Parameter(Tensor(out_features))
        self.glorot_init = glorot_init
        self.reset_parameters()

    def reset_parameters(self) -> None:
        if self.glorot_init:
            std = np.sqrt(2 / (self.in_features + self.out_features))
            self.weight.data.normal_(mean=0, std=std)
        else:
            self.weight.data.normal_(mean=0, std=0.25)
        init.zeros_(self.bias)

    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (*B, in_features)
        Output: shape (*B, out_features)
        """
        r = x.matmul(self.weight.T)
        r += self.bias
        return r


class Net(nn.Module):
    def __init__(self, glorot_init: bool = False, no_hidden_layers: int = 3) -> None:
        super().__init__()
        layers = []
        layers.append(Linear(784, 64, glorot_init=glorot_init))
        for _ in range(no_hidden_layers):
            layers.append(Linear(64, 64, glorot_init=glorot_init))
        layers.append(Linear(64, 10, glorot_init=glorot_init))
        self.fc = nn.ModuleList(layers)

    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (B, H=28, W=28)
        Output: shape (B, num_classes=10)
        """
        x = x.view(-1, 28 * 28)
        dropout = MujDropout()
        for i, layer in enumerate(self.fc):
            if i == len(self.fc) - 1:
                x = layer(x)
                x = dropout.forward(x)
            else:
                x = F.relu(layer(x))
        return x

# %%
class MnistTrainer:
    def __init__(self, batch_size: int = 128) -> None:
        transform = transforms.Compose([transforms.ToTensor()])
        self.trainset = torchvision.datasets.MNIST(
            root='./data', download=True, train=True, transform=transform
        )
        self.trainloader = torch.utils.data.DataLoader(
            self.trainset, batch_size=batch_size, shuffle=True, num_workers=2
        )
        self.testset = torchvision.datasets.MNIST(
            root='./data', train=False, download=True, transform=transform
        )
        self.testloader = torch.utils.data.DataLoader(
            self.testset, batch_size=1000, shuffle=False, num_workers=2
        )

    def train(
        self,
        net: nn.Module,
        gradient_visualizer: GradientVisualizer | None = None,
        epochs: int = 20,
        lr: float = 0.05,
        momentum: float = 0.9
    ) -> None:
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)
        log_freq = 100

        for epoch in range(epochs):
            net.train()
            running_loss = 0.0
            for i, data in enumerate(self.trainloader):
                inputs, labels = data
                optimizer.zero_grad()

                outputs = net(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                if gradient_visualizer is not None:
                    gradient_visualizer.visualize_gradients(lr, epoch, i)
                optimizer.step()

                running_loss += loss.item()
                if i % log_freq == log_freq - 1:
                    running_loss /= log_freq
                    print(f"epoch {epoch + 1:>5}, batch {i + 1:>5}, loss {running_loss:.3f}")
                    running_loss = 0.0
            self.test(net)

    def test(self, net: nn.Module) -> list[float]:
        net.eval()
        correct = 0
        total = 0
        all_gt_logits = []
        with torch.no_grad():
            for data in self.testloader:
                images, labels = data
                outputs = net(images)
                gt_logits = torch.gather(outputs, dim=1, index=labels.unsqueeze(-1))
                all_gt_logits.extend(float(logit.item()) for logit in gt_logits)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print(f"Accuracy of the network on the {total} test images: {correct / total:.2%}")
        return all_gt_logits

    def show_worst_misclassified(self, net: nn.Module, k: int = 10) -> None:
        all_gt_logits = self.test(net)
        _, indices = torch.topk(-torch.tensor(all_gt_logits), k)
        imgs = []
        labels = []
        for i in indices:
            img, label = self.testset[int(i.item())]
            imgs.append(img)
            labels.append(label)
        image = PIL.Image.fromarray(
            torch.cat(imgs, dim=-1).mul(255).to(torch.uint8).permute(1, 2, 0).numpy().squeeze()
        )
        display(image.resize((5 * image.width, 5 * image.height), PIL.Image.Resampling.NEAREST))
        print(labels)

# %%
epochs = 3
net = Net(glorot_init=True, no_hidden_layers=10)
trainer = MnistTrainer(batch_size=128)
trainer.train(net, None, epochs=3)
# Out:
# epoch     1, batch   100, loss 1.883
# epoch     1, batch   200, loss 1.027
# epoch     1, batch   300, loss 0.757
# epoch     1, batch   400, loss 0.653
# Accuracy of the network on the 10000 test images: 76.59%
# epoch     2, batch   100, loss 0.581
# epoch     2, batch   200, loss 0.526
# epoch     2, batch   300, loss 0.520
# epoch     2, batch   400, loss 0.493
# Accuracy of the network on the 10000 test images: 80.66%
# epoch     3, batch   100, loss 0.460
# epoch     3, batch   200, loss 0.459
# epoch     3, batch   300, loss 0.457
# epoch     3, batch   400, loss 0.453
# Accuracy of the network on the 10000 test images: 80.77%

# %% [markdown]
# # Zadanie 6 - batch normalization

# %%
class BatchNorm(nn.Module):
    def __init__(self, num_features: int, momentum: float = 0.1, eps: float = 1e-5):
        super().__init__()
        self.num_features = num_features
        self.momentum = momentum
        self.eps = eps

        # Learnable parameters
        self.gamma = nn.Parameter(torch.ones(num_features))
        self.beta = nn.Parameter(torch.zeros(num_features))

        # Running stats (buffers = not trained by optimizer)
        self.register_buffer("running_mean", torch.zeros(num_features))
        self.register_buffer("running_var", torch.ones(num_features))

    def forward(self, x: Tensor) -> Tensor:
        if self.training:
            batch_mean = x.mean(dim=0)
            batch_var = x.var(dim=0, unbiased=False)

            # Update running stats
            self.running_mean = (1 - self.momentum) * self.running_mean + self.momentum * batch_mean
            self.running_var = (1 - self.momentum) * self.running_var + self.momentum * batch_var

            mean, var = batch_mean, batch_var
        else:
            mean, var = self.running_mean, self.running_var

        # Normalize
        x_hat = (x - mean) / torch.sqrt(var + self.eps)

        # Scale and shift
        return self.gamma * x_hat + self.beta

# %%
class Linear(nn.Module):
    def __init__(self, in_features: int, out_features: int, glorot_init: bool) -> None:
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(Tensor(out_features, in_features))
        self.bias = nn.Parameter(Tensor(out_features))
        self.glorot_init = glorot_init
        self.reset_parameters()

    def reset_parameters(self) -> None:
        if self.glorot_init:
            std = np.sqrt(2 / (self.in_features + self.out_features))
            self.weight.data.normal_(mean=0, std=std)
        else:
            self.weight.data.normal_(mean=0, std=0.25)
        init.zeros_(self.bias)

    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (*B, in_features)
        Output: shape (*B, out_features)
        """
        r = x.matmul(self.weight.T)
        r += self.bias
        return r

class Net(nn.Module):
    def __init__(self, glorot_init: bool = False, no_hidden_layers: int = 3) -> None:
        super().__init__()
        layers = []

        # Input layer
        layers.append(Linear(784, 64, glorot_init=glorot_init))
        layers.append(BatchNorm(64))

        # Hidden layers
        for _ in range(no_hidden_layers):
            layers.append(Linear(64, 64, glorot_init=glorot_init))
            layers.append(BatchNorm(64))

        # Output layer (no BN here)
        layers.append(Linear(64, 10, glorot_init=glorot_init))

        self.fc = nn.ModuleList(layers)

    def forward(self, x: Tensor) -> Tensor:
        x = x.view(-1, 28 * 28)
        for i, layer in enumerate(self.fc):
            if isinstance(layer, Linear) and i == len(self.fc) - 1:
                # last linear → logits
                x = layer(x)
            elif isinstance(layer, Linear):
                # linear → BN → ReLU
                x = self.fc[i + 1](layer(x))   # batchnorm
                x = F.relu(x)
            else:
                continue  # skip BN because it's applied directly above
        return x

# %%
class MnistTrainer:
    def __init__(self, batch_size: int = 128) -> None:
        transform = transforms.Compose([transforms.ToTensor()])
        self.trainset = torchvision.datasets.MNIST(
            root='./data', download=True, train=True, transform=transform
        )
        self.trainloader = torch.utils.data.DataLoader(
            self.trainset, batch_size=batch_size, shuffle=True, num_workers=2
        )
        self.testset = torchvision.datasets.MNIST(
            root='./data', train=False, download=True, transform=transform
        )
        self.testloader = torch.utils.data.DataLoader(
            self.testset, batch_size=1000, shuffle=False, num_workers=2
        )

    def train(
        self,
        net: nn.Module,
        gradient_visualizer: GradientVisualizer | None = None,
        epochs: int = 20,
        lr: float = 0.05,
        momentum: float = 0.9
    ) -> None:
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)
        log_freq = 100

        for epoch in range(epochs):
            net.train()
            running_loss = 0.0
            for i, data in enumerate(self.trainloader):
                inputs, labels = data
                optimizer.zero_grad()

                outputs = net(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                if gradient_visualizer is not None:
                    gradient_visualizer.visualize_gradients(lr, epoch, i)
                optimizer.step()

                running_loss += loss.item()
                if i % log_freq == log_freq - 1:
                    running_loss /= log_freq
                    print(f"epoch {epoch + 1:>5}, batch {i + 1:>5}, loss {running_loss:.3f}")
                    running_loss = 0.0
            self.test(net)

    def test(self, net: nn.Module) -> list[float]:
        net.eval()
        correct = 0
        total = 0
        all_gt_logits = []
        with torch.no_grad():
            for data in self.testloader:
                images, labels = data
                outputs = net(images)
                gt_logits = torch.gather(outputs, dim=1, index=labels.unsqueeze(-1))
                all_gt_logits.extend(float(logit.item()) for logit in gt_logits)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print(f"Accuracy of the network on the {total} test images: {correct / total:.2%}")
        return all_gt_logits

    def show_worst_misclassified(self, net: nn.Module, k: int = 10) -> None:
        all_gt_logits = self.test(net)
        _, indices = torch.topk(-torch.tensor(all_gt_logits), k)
        imgs = []
        labels = []
        for i in indices:
            img, label = self.testset[int(i.item())]
            imgs.append(img)
            labels.append(label)
        image = PIL.Image.fromarray(
            torch.cat(imgs, dim=-1).mul(255).to(torch.uint8).permute(1, 2, 0).numpy().squeeze()
        )
        display(image.resize((5 * image.width, 5 * image.height), PIL.Image.Resampling.NEAREST))
        print(labels)

# %%
epochs = 3
net = Net(glorot_init=True, no_hidden_layers=10)
trainer = MnistTrainer(batch_size=128)
trainer.train(net, None, epochs=3)
# Out:
# epoch     1, batch   100, loss 0.805
# epoch     1, batch   200, loss 0.347
# epoch     1, batch   300, loss 0.263
# epoch     1, batch   400, loss 0.221
# Accuracy of the network on the 10000 test images: 95.03%
# epoch     2, batch   100, loss 0.174
# epoch     2, batch   200, loss 0.175
# epoch     2, batch   300, loss 0.164
# epoch     2, batch   400, loss 0.163
# Accuracy of the network on the 10000 test images: 96.49%
# epoch     3, batch   100, loss 0.129
# epoch     3, batch   200, loss 0.130
# epoch     3, batch   300, loss 0.127
# epoch     3, batch   400, loss 0.112
# Accuracy of the network on the 10000 test images: 97.07%

# %% [markdown]
# # CNN
# Design and implement a simple convolutional network and achieve 99% test accuracy (in up to 10 epochs, 5 should be enough). The architecture is up to you, but even a few convolutional layers should be enough.
# You may use `torch.nn.Conv2d, BatchNorm2d, MaxPool2d, ReLU, Dropout2d, Linear, Flatten, BatchNorm1d`.
# Don't make it too generic, just try a few fixed layers.

# %%
class TestCNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),

            nn.MaxPool2d(2, 2),

            nn.Dropout2d(0.1),

            nn.Conv2d(32, 64, kernel_size=4),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.MaxPool2d(2, 2),

            nn.Dropout2d(0.2137)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(1600, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.67),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)

        return x

# %%
net = TestCNN()
trainer = MnistTrainer(batch_size=128)
trainer.train(net, epochs=5, lr=0.01)
# Out:
# epoch     1, batch   100, loss 0.602
# epoch     1, batch   200, loss 0.221
# epoch     1, batch   300, loss 0.175
# epoch     1, batch   400, loss 0.151
# Accuracy of the network on the 10000 test images: 98.45%
# epoch     2, batch   100, loss 0.122
# epoch     2, batch   200, loss 0.110
# epoch     2, batch   300, loss 0.099
# epoch     2, batch   400, loss 0.102
# Accuracy of the network on the 10000 test images: 98.73%
# epoch     3, batch   100, loss 0.087
# epoch     3, batch   200, loss 0.087
# epoch     3, batch   300, loss 0.084
# epoch     3, batch   400, loss 0.082
# Accuracy of the network on the 10000 test images: 98.86%
# epoch     4, batch   100, loss 0.075
# epoch     4, batch   200, loss 0.073
# epoch     4, batch   300, loss 0.069
# epoch     4, batch   400, loss 0.076
# Accuracy of the network on the 10000 test images: 98.95%
# epoch     5, batch   100, loss 0.068
# epoch     5, batch   200, loss 0.067
# epoch     5, batch   300, loss 0.062
# epoch     5, batch   400, loss 0.060
# Accuracy of the network on the 10000 test images: 99.18%
