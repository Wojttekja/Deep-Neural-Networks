# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# Code based on https://github.com/pytorch/examples/blob/master/mnist/main.py
#
# In this exercise, we are using high-level abstractions from torch.nn like nn.Linear.
# Note: during the next lab session we will go one level deeper and implement more things
# with bare hands.
#
# Tasks:
#
#  1. Read the code.
#
#  2. Check that the given implementation reaches 95% test accuracy for architecture input-128-128-10 after few epochs.
#
#  3. Add the option to use SGD with momentum instead of ADAM.
#
#  4. Experiment with different learning rates. Use the provided TrainingVisualizer
#  to plot the learning curves and gradient-to-weight ratios. Compare visualizations
#  for different learning rates for both ADAM and SGD with momentum.
#
#  5. Parameterize the constructor by a list of sizes of hidden layers of the MLP.
#  Note that this requires creating a list of layers as an attribute of the Net class,
#  and one can't use a standard Python list containing nn.Modules (why?).
#  Check torch.nn.ModuleList.
#
# If you run this notebook locally then you may need to install some packages.
# It may be achieved by adding the following code cell to the notebook and running it:
# ```
# !pip install torch torchvision plotly ipywidgets
# ```
# This notebook can also utilize Colab GPU. However, remember to kill your GPU session after classes as otherwise, you may use all your free GPU time for this week.

# %%
import math
import sys

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import plotly.graph_objects as go
from torch import Tensor
from torchvision import datasets, transforms

# Allow custom (non-ipywidget) widgets.
if "google.colab" in sys.modules:
    from google.colab import output

    output.enable_custom_widget_manager()

# For reproducibility.
torch.manual_seed(1)

# %% [markdown]
# ## Tensors
# In ML, *tensor* is just a short name for an n-dimensional array.
#
# In other areas like physics, it might mean a multilinear operation that can be represented, after a choice of basis, by an ndarray; this is where we would see all the extra stuff (like covariance/contravariance), like for example on the Wikipedia article for "tensor". For us, it's usually just a bunch of numbers.
#
# torch.Tensor is can be thought of as a wrapper around numpy ndarray, but:
# * the interface is slightly different (like `np.expand_dims(x, dim=n-1)` vs `torch.unsqueeze(x, axis=-1)`);
# * the data can be stored in GPU memory (or others);
# * it can be part of a computation graph: a computed Tensor has pointers to other Tensors it was computed from, and to functions computing partial derivatives.
#
# All the operations defined on for a torch.Tensor (`@`, `.arctan`, `.unsqueeze`, and a hundred others) can also run on a GPU and

# %%
x_np = np.array([[0, 1, 2], [3, 4, 5]])
x = torch.tensor([[0, 1, 2], [3, 4, 5]])  # Also: torch.rand, ones, zeros, rand_like, ...
display(x_np, x)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])
# tensor([[0, 1, 2],
#         [3, 4, 5]])

# %%
torch.from_numpy(x_np).equal(x), np.array_equal(x_np, x.numpy())
# Out:
# (True, True)

# %%
x.shape, x.dtype, x.device, x.requires_grad
# Out:
# (torch.Size([2, 3]), torch.int64, device(type='cpu'), False)

# %% [markdown]
# Most operations have an in-place variant with the same name, but with an underscore.
# This forgets the original value, making the computation of gradients impossible, so most of the time we don't use in-place operations.

# %%
x.add_(2)
display(x)
# Out:
# tensor([[2, 3, 4],
#         [5, 6, 7]])

# %% [markdown]
# ## Autograd
# Operations on torch tensors remember the computation graph.
# This allows to compute the gradient of e.g. a loss node over all other nodes with loss.backward().

# %%
x = torch.tensor([[0., 1., 2.], [3., 4., 5.]], requires_grad=True)
y = torch.sigmoid(x)
loss = (((y - 1) ** 2).mean())
print("x", x.grad_fn, ", y", y.grad_fn, ", loss", loss.grad_fn)
print(loss.grad_fn.next_functions)  # type: ignore
print(loss.grad_fn.next_functions[0][0].next_functions)  # type: ignore
# Out:
# x None , y <SigmoidBackward0 object at 0x7fd5f73b0c40> , loss <MeanBackward0 object at 0x7fd5f7567850>
# ((<PowBackward0 object at 0x7fd5f7567850>, 0),)
# ((<SubBackward0 object at 0x7fd5f73b0c40>, 0),)

# %% [markdown]
# The method Tensor.backward():
# * for each node with `requires_grad`: computes the gradients from each .grad_fn and propagates it using the chain rule.
# * for each leaf node (`requires_grad` with no predecessors that `requires_grad`): accumulates the gradient into the tensor’s `.grad` attribute.

# %%
loss.backward()
x.grad
# Out:
# tensor([[-4.1667e-02, -1.7626e-02, -4.1719e-03],
#         [-7.1418e-04, -1.0590e-04, -1.4831e-05]])

# %% [markdown]
# We say *accumulates* not *stores*, because if .grad already exists, `backward()` adds to it, instead of replacing it.

# %%
loss2 = ((x * 0).mean())
loss2.backward()
x.grad
# Out:
# tensor([[-4.1667e-02, -1.7626e-02, -4.1719e-03],
#         [-7.1418e-04, -1.0590e-04, -1.4831e-05]])

# %% [markdown]
# During (for example) evaluation, you don't need to store the computational graph, so you can disable it:

# %%
with torch.no_grad():
    y = x * x

print(y.grad_fn)
# Out:
# None

# %% [markdown]
# In some situations you may need more fine-grained control.
# You can detach a tensor from the graph, to treat it like a constant tensor.

# %%
y = x * x
print(y.grad_fn, y.requires_grad)
y = y.detach()  # Not in-place, returns a new tensor with the same data.
print(y.grad_fn, y.requires_grad)
# Out:
# <MulBackward0 object at 0x7fd6fc257f40> True
# None False

# %% [markdown]
# ## Modules
# A torch **module** (not *model*) is essentially just an object with a `forward()` method, usually `forward(x: Tensor) -> Tensor`.
# A network (model) is built as a large module that contains and calls smaller modules, which themselves contain even smaller modules.
#
# Basically any callable could be a module, but subclassing `nn.Module` adds features like:
# * automatically registering and enumerating submodules and trainable parameters,
# * serializing and storing parameters into files,
# * adding hooks in the middle of existing models.

# %%
class MyLinear(nn.Module):
    """
    This is essentially the same as nn.Linear.

    Compare: https://github.com/pytorch/pytorch/blob/v2.9.0/torch/nn/modules/linear.py#L53
    """
    def __init__(self, in_features: int, out_features: int) -> None:
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features

        self.weight = nn.Parameter(torch.empty((out_features, in_features)))
        self.bias = nn.Parameter(torch.empty(out_features))

        self.reset_parameters()

    def reset_parameters(self) -> None:
        # The initialization used by PyTorch by default, including non-zero biases.
        bound = 1 / math.sqrt(self.in_features)
        nn.init.uniform_(self.weight, -bound, bound)
        nn.init.uniform_(self.bias, -bound, bound)

    def forward(self, input: Tensor) -> Tensor:
        """
        Input shape: (B*, in_features).
        Output shape: (B*, out_features).
        """
        return input @ self.weight.T + self.bias

# %% [markdown]
# We define the module behaviour in the **`forward()`** method, not in the special `__call__()`.<br>
# However, we then use the module directly as a callable, `module()`.<br>
# This will call `module.forward()`, but can also calls hooks, if any are defined.

# %%
module = MyLinear(2, 3)
x = torch.rand((7, 5, 2))
y = module(x)
y.shape
# Out:
# torch.Size([7, 5, 3])

# %% [markdown]
# The class **nn.Parameter** just wraps a tensor to indicate that this is a trainable parameter, and changes the default `requires_grad`.<br>
# When an nn.Parameter is assigned to a field of an nn.Module, it automatically registers it,
# so that all parameters of this modules and its submodules can be easily accessed.

# %%
for i, (name, param) in enumerate(module.named_parameters()):
    print(f'{i}. "{name}":\t{param}\n')
# Out:
# 0. "weight":	Parameter containing:
# tensor([[ 0.3559, -0.4972],
#         [-0.5335,  0.0430],
#         [-0.1205,  0.4153]], requires_grad=True)
#
# 1. "bias":	Parameter containing:
# tensor([-0.4095, -0.6286,  0.5146], requires_grad=True)

# %% [markdown]
# ## A basic Net

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (B, 28, 28).
        Output: class probabilities (after softmax), shape (B, 10).
        """
        x = torch.flatten(x, start_dim=1)  # (B, 728)
        x = self.fc1(x)  # (B, 128)
        x = F.relu(x)
        x = self.fc2(x)  # (B, 128)
        x = F.relu(x)
        x = self.fc3(x)  # (B, 10)
        output = F.log_softmax(x, dim=1)
        return output

# %% [markdown]
# Assigning to a nn.Module to a field of nn.Module automatically registers it as a submodule.<br>
# You can iterate over all submodules (recursively) with `.named_modules()` or over direct children only with `.named_children()`.

# %%
net = Net()
for i, (name, submodule) in enumerate(net.named_modules()):
    print(f'{i}. "{name}":\t{submodule}')
# Out:
# 0. "":	Net(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=10, bias=True)
# )
# 1. "fc1":	Linear(in_features=784, out_features=128, bias=True)
# 2. "fc2":	Linear(in_features=128, out_features=128, bias=True)
# 3. "fc3":	Linear(in_features=128, out_features=10, bias=True)

# %% [markdown]
# The `.train()` and `.eval()` methods set the `training` flag of a module and all its submodules.<br>
# This changes the behaviour of certain modules like BatchNorm and Dropout (see next labs).
#
# Forgetting to switch the training mode is a common bug that can cause weird behaviour.

# %%
net.train()
print(net.fc1.training)
net.eval()
print(net.fc1.training)
# Out:
# True
# False

# %% [markdown]
# Note that operations on a module (`.train()`, `.eval()`, `.to(dtype)`, `.to(device)`) modify it in-place.<br>
# Operations on a tensor without a trailing underscore (including `.to(dtype)`, `.to(device)`) return a new tensor and leave the original unchanged

# %% [markdown]
# ## Train and test code

# %%
# @title <small>Helper class: TrainingVisualizer</small>

class TrainingVisualizer:
    def __init__(self, log_interval: int = 10):
        self.log_interval = log_interval
        self.train_loss_fig = self.init_line_plot(
            title="Training loss", xaxis_title="Step"
        )
        self.grad_to_weight_fig = self.init_line_plot(
            title="Gradient standard deviation to weight standard deviation ratio at 1st layer",
            xaxis_title="Step",
            yaxis_title="Gradient to weight ratio (log scale)",
            yaxis_type="log",
        )
        self.test_acc_fig = self.init_line_plot(
            title="Test accuracy", x=[], xaxis_title="Epoch", mode="lines+markers"
        )

        # Parameters related to current tracked model and its training
        self.first_linear_layer = None
        self.lr = None
        self.trace_idx = -1

    def init_line_plot(
        self,
        title: str,
        x=None,
        xaxis_title: str | None = None,
        yaxis_title: str | None = None,
        yaxis_type: str = "linear",
        mode: str = "lines",
    ) -> go.FigureWidget:
        fig = go.Figure()
        fig.update_layout(
            title=title,
            title_x=0.5,
            xaxis_title=xaxis_title,
            yaxis_title=yaxis_title,
            height=400,
            width=1500,
            margin=dict(b=10, t=60),
        )
        fig.update_yaxes(type=yaxis_type)
        # We cannot add new traces dynamically because Colab has a problem with widgets
        # from plotly (traces added dynamically are rendered twice).
        # As an ugly workaround we create a lot of empty traces and update them later
        # with actual data. Empty traces are not plotted.
        for _ in range(25):
            fig.add_trace(go.Scatter(x=x, y=[], showlegend=True, mode=mode))

        fig_widget = go.FigureWidget(fig)
        display(fig_widget)
        return fig_widget

    def track_model(
        self, model: torch.nn.Module, optimizer: torch.optim.Optimizer, lr: float
    ) -> None:
        """
        Start tracking training metrics for a new model.
        """

        for field in model.__dict__["_modules"].values():
            if isinstance(field, nn.Linear):
                self.first_linear_layer = field
                break
            elif isinstance(field, nn.ModuleList):
                self.first_linear_layer = field[0]
                break

        self.lr = lr
        self.trace_idx += 1

        optim_name = type(optimizer).__name__
        self.train_loss_fig.data[self.trace_idx].name = f"{optim_name}, {lr}"
        self.grad_to_weight_fig.data[self.trace_idx].name = f"{optim_name}, {lr}"
        self.test_acc_fig.data[self.trace_idx].name = f"{optim_name}, {lr}"

    def plot_gradients_and_loss(self, batch_idx: int, loss: float) -> None:
        if batch_idx % self.log_interval == 0:
            self.train_loss_fig.data[self.trace_idx].y += (loss,)

            layer = self.first_linear_layer
            grad_to_weight_ratio = (
                self.lr * layer.weight.grad.std() / layer.weight.std()
            ).item()

            self.grad_to_weight_fig.data[self.trace_idx].y += (grad_to_weight_ratio,)

    def plot_accuracy(self, epoch: int, accuracy: float) -> None:
        self.test_acc_fig.data[self.trace_idx].x += (epoch,)
        self.test_acc_fig.data[self.trace_idx].y += (accuracy,)

# %%
def train_epoch(
    model: torch.nn.Module,
    device: torch.device,
    train_loader: torch.utils.data.DataLoader,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    log_interval: int,
    visualizer: TrainingVisualizer,
    verbose: bool = False,
) -> None:
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # Move data to the device (e.g. GPU #0) where model parameters are.
        data, target = data.to(device), target.to(device)

        # Since `backward()` will accumuate gradients, remember to reset them.
        optimizer.zero_grad()

        # Forward pass.
        output = model(data)  # Logs of class probabilites, shape (B, 10)
        loss = F.nll_loss(output, target)  # Shape (1,)

        # Backward pass.
        loss.backward()

        visualizer.plot_gradients_and_loss(batch_idx, loss.item())

        # For each parameter, updates the tensor's value using its .grad.
        optimizer.step()

        if batch_idx % log_interval == 0:
            if verbose:
                done, total = batch_idx * len(data), len(train_loader.dataset)
                print(
                    f"Train Epoch: {epoch} [{done}/{total} images ({done / total:.0%})]\t"
                    + f"Loss: {loss.item():.6f}"
                )

# %%
def test(
    model: torch.nn.Module,
    device: torch.device,
    test_loader: torch.utils.data.DataLoader,
    epoch: int,
    visualizer: TrainingVisualizer,
    verbose: bool = False,
) -> None:
    model.eval()
    test_loss = 0
    n_correct = 0
    n_total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            # Accumulate sum of dataitem losses and only divide by n_total at the end.
            test_loss += F.nll_loss(output, target, reduction="sum").item()
            pred = output.argmax(dim=1)
            n_correct += (pred == target).sum().item()
            n_total += len(target)

    test_loss /= n_total

    if verbose:
        print(f"\nTest loss: {test_loss:.4f}, Accuracy: {n_correct}/{n_total} ({n_correct/n_total:.0%})\n")
    visualizer.plot_accuracy(epoch, 100.0 * n_correct / n_total)

# %% [markdown]
# ## Hyperparameters

# %%
# Training uses more memory than test (due to gradient computations),
# so we can set test_batch_size to be larger.
epochs = 5
batch_size = 256
test_batch_size = 1000
lr = 1e-2
log_interval = 10

# Use CUDA if a CUDA GPU is available, otherwise we'll run on CPU.
# You could also use "mps" for Apple Silicon, and some others,
# though support for less common operations may vary.
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# ## Dataset and dataloader
# Any sequence of dataitems (and even some iterables) can be used as a ***dataset***.<br>
# A dataitem can be for example an (input image, output label) pair.<br>
# Torch datasets usually allow passing a transformation: it is then applied whenever you retrieve an item with `dataset[i]`.
#
# A ***dataloader*** manages parallel loading (it can create worker threads that call `dataset[i]` in parallel), batching, shuffling, sometimes moving data between devices.

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(mean=(0.1307,), std=(0.3081,))]
)
train_dataset = datasets.MNIST("../data", train=True, download=True, transform=transform)
test_dataset = datasets.MNIST("../data", train=False, transform=transform)
len(train_dataset), len(test_dataset)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.3MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 492kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.61MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.00MB/s]
# (60000, 10000)

# %%
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, **kwargs)

# %% [markdown]
# ## Running it all

# %%
model = Net().to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)

visualizer = TrainingVisualizer(log_interval=log_interval)
visualizer.track_model(model, optimizer, lr)

for epoch in range(1, epochs + 1):
    train_epoch(
        model,
        device,
        train_loader,
        optimizer,
        epoch,
        log_interval,
        visualizer,
        verbose=True,
    )
    test(model, device, test_loader, epoch, visualizer, verbose=True)
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6e54a87a-7a13-4fd1-b9b9-4a7fa9c3cc06',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '81215505-caa7-4a26-83f0-5fd5b52838fe',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '52c5e4e3-febe-4bdd-bb29-f849d126f67f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '49a96176-98a2-47c9-b4e4-f19a1107bae1',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5b95803c-09d2-4623-81f8-cf777301cc6b',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '28f43c13-caae-4fcf-b58a-60cd930676ec',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b7eddbb3-434a-4dfa-853c-32719aee5e41',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '503fd549-6f2c-4729-8239-e96d15a09aa9',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7ef335f3-c18c-4bef-a1c2-d7419898422d',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '85d51489-1557-4092-8c16-c31a66834dea',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '35c8237d-4a0d-433f-a2c5-86d23317d590',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'de8b4df4-1c0d-45d5-ae93-a2438c855fec',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c3cc5098-1c78-4acc-9f30-1d86cbfc395b',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'dbaa877c-18c3-4446-8f8e-45d54528f0e8',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c449c028-dc90-4214-a2db-e65db515a5e6',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6c8127cc-a727-4894-8d10-c6381acbe8df',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8fb908a2-02ec-404d-a725-6e2c3d0d67be',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5a45f54d-4a4a-4352-8fe2-ce4a89c34755',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e71ecca3-4583-47dd-bb69-f9e58dbe4921',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '98b86f34-569f-4bd5-985f-ea57b3de2eff',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0e3fc511-b518-4239-a2a4-320b8b80715f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'aaf174d4-2c18-4a54-b734-283784025880',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1e6bbe2c-d00e-4e6a-8add-fd8dee79018c',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '04d4b09e-b2ff-4c7b-8a50-cb31a8d02787',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a13dadf1-bfca-4a6f-8388-491a8b5cadae',
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Training loss', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Step'}},
#                'yaxis': {'type': 'linear'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6579e80d-a69b-4fac-9443-fbff8d73f467',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '224c2264-97c9-4f9e-b01f-13389373237a',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a3a9fda0-f2b1-4f5f-ad81-fb649a94789f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7e0df70f-4828-46fd-9d9d-07df11a4124a',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '59bef825-6ba7-45ec-8512-9ce3ffe8375b',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c1e5e5e6-daa3-4f69-9c35-13e4ea56afb2',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fbb629ba-06ba-40f8-bc96-eb85e7d8998d',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ed90651b-0f79-4d91-a6dc-f8e5b5b91ff6',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '779fbee9-178f-4035-881e-7e5f4d783ed7',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '52c9a7d1-ca1e-4973-a6e1-06ad975ba7a5',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '62e159d8-c444-4ad7-818c-f85d0d94a942',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9f7cc97f-eb31-4bd4-9480-fdd8e704589b',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '707cde84-6ca0-41f9-9c95-19c41bab8af8',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '154fd040-17e8-45b6-8ca0-8b08665dbd1e',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ba57b0dd-bc14-4fd6-a42d-700fc73a368a',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '28566deb-1d16-49a2-bc73-9ccd7e6f810e',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '14354974-38b0-4170-b935-af226db225b7',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '45591865-1541-4f67-b444-35c435256875',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '68b39097-b3ec-4b14-99e5-4878eabc6a63',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'aadd1ada-c890-497f-8fb5-393818d63ba0',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '49253e78-995f-44a2-9d2a-100b10b71bf9',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '735c43c5-409d-477f-9683-dc139c800c79',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '137f0372-e99c-46c1-a156-fe033b94a7d1',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5e253a43-1eaa-406a-9d7e-e948b13ba5d8',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e9148965-8208-4549-a68c-168fc3e5730b',
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient standard deviation to weight standard deviation ratio at 1st layer', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Step'}},
#                'yaxis': {'title': {'text': 'Gradient to weight ratio (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5918d963-9ac8-4417-bd3c-f9e0e7f87ba4',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '856d7560-c971-4614-bc4b-0f2df76ecf02',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd70b47e9-2f7b-40fd-8253-b4162fb7464a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '27538194-b077-484c-a704-3be15ff212cd',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'acd653ea-41b2-499b-a275-6daa648a27a8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '69e00298-4e25-4809-be42-f0b087d07ff8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e8c879da-38e2-4b13-bd8a-c95e45e48af1',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd5f23431-1e44-49e8-a7e8-5441f9186fe0',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a10aaa98-b5b3-4e44-bf4c-69fd0598f10e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '50198e7b-8c9b-46eb-8fc1-38772a94d87a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '46a4748d-366c-40da-9f0d-ef37a325c8eb',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '77e76f9e-9b49-4a58-8d82-e1684c3ac67c',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '10e103fe-0bcf-4828-8e49-b7f69eecb54a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '50e891cb-94e0-48c5-84af-83fdea7fae19',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0754d555-bb93-4ee2-aa0f-fb33e86a2438',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '50834cf6-b29e-49a5-adff-c0e87e667ce9',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3f10574b-d0ed-47b1-86e8-59ebd1d845aa',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ab424371-7399-46ac-a621-9ca96ad1fcbd',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '375c19f8-0ba5-41f6-b9e9-4312744b132e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '914db0d1-73fb-42c9-b41d-be4888894faf',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4714e72f-1612-42b8-9651-0547faef40c0',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd54b4d9d-2e2e-43a6-93c0-37cb0b05ff1a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'cc51c0bf-c509-4072-aea3-9acd5cb2e520',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4c6c8022-2347-4fdd-bfab-1cca5ead7a97',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a4eba4a7-e367-4927-ad32-93ef1acc9263',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Test accuracy', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Epoch'}},
#                'yaxis': {'type': 'linear'}}
# })
# Train Epoch: 1 [0/60000 images (0%)]	Loss: 2.317030
# Train Epoch: 1 [2560/60000 images (4%)]	Loss: 0.662510
# Train Epoch: 1 [5120/60000 images (9%)]	Loss: 0.354210
# Train Epoch: 1 [7680/60000 images (13%)]	Loss: 0.219290
# Train Epoch: 1 [10240/60000 images (17%)]	Loss: 0.192017
# Train Epoch: 1 [12800/60000 images (21%)]	Loss: 0.250033
# Train Epoch: 1 [15360/60000 images (26%)]	Loss: 0.207822
# Train Epoch: 1 [17920/60000 images (30%)]	Loss: 0.164854
# Train Epoch: 1 [20480/60000 images (34%)]	Loss: 0.174407
# Train Epoch: 1 [23040/60000 images (38%)]	Loss: 0.213493
# Train Epoch: 1 [25600/60000 images (43%)]	Loss: 0.145839
# Train Epoch: 1 [28160/60000 images (47%)]	Loss: 0.282199
# Train Epoch: 1 [30720/60000 images (51%)]	Loss: 0.195962
# Train Epoch: 1 [33280/60000 images (55%)]	Loss: 0.142907
# Train Epoch: 1 [35840/60000 images (60%)]	Loss: 0.282652
# Train Epoch: 1 [38400/60000 images (64%)]	Loss: 0.122154
# Train Epoch: 1 [40960/60000 images (68%)]	Loss: 0.175228
# Train Epoch: 1 [43520/60000 images (73%)]	Loss: 0.158247
# Train Epoch: 1 [46080/60000 images (77%)]	Loss: 0.113663
# Train Epoch: 1 [48640/60000 images (81%)]	Loss: 0.236025
# Train Epoch: 1 [51200/60000 images (85%)]	Loss: 0.244894
# Train Epoch: 1 [53760/60000 images (90%)]	Loss: 0.098893
# Train Epoch: 1 [56320/60000 images (94%)]	Loss: 0.159321
# Train Epoch: 1 [58880/60000 images (98%)]	Loss: 0.117605
#
# Test loss: 0.1676, Accuracy: 9519/10000 (95%)
#
# Train Epoch: 2 [0/60000 images (0%)]	Loss: 0.084042
# Train Epoch: 2 [2560/60000 images (4%)]	Loss: 0.189300
# Train Epoch: 2 [5120/60000 images (9%)]	Loss: 0.138010
# Train Epoch: 2 [7680/60000 images (13%)]	Loss: 0.201900
# Train Epoch: 2 [10240/60000 images (17%)]	Loss: 0.154674
# Train Epoch: 2 [12800/60000 images (21%)]	Loss: 0.121984
# Train Epoch: 2 [15360/60000 images (26%)]	Loss: 0.133903
# Train Epoch: 2 [17920/60000 images (30%)]	Loss: 0.156344
# Train Epoch: 2 [20480/60000 images (34%)]	Loss: 0.097534
# Train Epoch: 2 [23040/60000 images (38%)]	Loss: 0.214358
# Train Epoch: 2 [25600/60000 images (43%)]	Loss: 0.114257
# Train Epoch: 2 [28160/60000 images (47%)]	Loss: 0.088919
# Train Epoch: 2 [30720/60000 images (51%)]	Loss: 0.140662
# Train Epoch: 2 [33280/60000 images (55%)]	Loss: 0.125925
# Train Epoch: 2 [35840/60000 images (60%)]	Loss: 0.105602
# Train Epoch: 2 [38400/60000 images (64%)]	Loss: 0.075295
# Train Epoch: 2 [40960/60000 images (68%)]	Loss: 0.201668
# Train Epoch: 2 [43520/60000 images (73%)]	Loss: 0.100597
# Train Epoch: 2 [46080/60000 images (77%)]	Loss: 0.081121
# Train Epoch: 2 [48640/60000 images (81%)]	Loss: 0.108979
# Train Epoch: 2 [51200/60000 images (85%)]	Loss: 0.090422
# Train Epoch: 2 [53760/60000 images (90%)]	Loss: 0.189784
# Train Epoch: 2 [56320/60000 images (94%)]	Loss: 0.140624
# Train Epoch: 2 [58880/60000 images (98%)]	Loss: 0.108701
#
# Test loss: 0.1325, Accuracy: 9592/10000 (96%)
#
# Train Epoch: 3 [0/60000 images (0%)]	Loss: 0.138726
# Train Epoch: 3 [2560/60000 images (4%)]	Loss: 0.121876
# Train Epoch: 3 [5120/60000 images (9%)]	Loss: 0.119049
# Train Epoch: 3 [7680/60000 images (13%)]	Loss: 0.063542
# Train Epoch: 3 [10240/60000 images (17%)]	Loss: 0.084257
# Train Epoch: 3 [12800/60000 images (21%)]	Loss: 0.195818
# Train Epoch: 3 [15360/60000 images (26%)]	Loss: 0.197891
# Train Epoch: 3 [17920/60000 images (30%)]	Loss: 0.091191
# Train Epoch: 3 [20480/60000 images (34%)]	Loss: 0.157808
# Train Epoch: 3 [23040/60000 images (38%)]	Loss: 0.082122
# Train Epoch: 3 [25600/60000 images (43%)]	Loss: 0.138880
# Train Epoch: 3 [28160/60000 images (47%)]	Loss: 0.081624
# Train Epoch: 3 [30720/60000 images (51%)]	Loss: 0.104860
# Train Epoch: 3 [33280/60000 images (55%)]	Loss: 0.097244
# Train Epoch: 3 [35840/60000 images (60%)]	Loss: 0.083471
# Train Epoch: 3 [38400/60000 images (64%)]	Loss: 0.095129
# Train Epoch: 3 [40960/60000 images (68%)]	Loss: 0.084389
# Train Epoch: 3 [43520/60000 images (73%)]	Loss: 0.046578
# Train Epoch: 3 [46080/60000 images (77%)]	Loss: 0.161756
# Train Epoch: 3 [48640/60000 images (81%)]	Loss: 0.106019
# Train Epoch: 3 [51200/60000 images (85%)]	Loss: 0.063957
# Train Epoch: 3 [53760/60000 images (90%)]	Loss: 0.116389
# Train Epoch: 3 [56320/60000 images (94%)]	Loss: 0.086960
# Train Epoch: 3 [58880/60000 images (98%)]	Loss: 0.092777
#
# Test loss: 0.1304, Accuracy: 9651/10000 (97%)
#
# Train Epoch: 4 [0/60000 images (0%)]	Loss: 0.076934
# Train Epoch: 4 [2560/60000 images (4%)]	Loss: 0.166746
# Train Epoch: 4 [5120/60000 images (9%)]	Loss: 0.058203
# Train Epoch: 4 [7680/60000 images (13%)]	Loss: 0.160635
# Train Epoch: 4 [10240/60000 images (17%)]	Loss: 0.116111
# Train Epoch: 4 [12800/60000 images (21%)]	Loss: 0.071682
# Train Epoch: 4 [15360/60000 images (26%)]	Loss: 0.039551
# Train Epoch: 4 [17920/60000 images (30%)]	Loss: 0.105691
# Train Epoch: 4 [20480/60000 images (34%)]	Loss: 0.051143
# Train Epoch: 4 [23040/60000 images (38%)]	Loss: 0.145402
# Train Epoch: 4 [25600/60000 images (43%)]	Loss: 0.104823
# Train Epoch: 4 [28160/60000 images (47%)]	Loss: 0.064900
# Train Epoch: 4 [30720/60000 images (51%)]	Loss: 0.094192
# Train Epoch: 4 [33280/60000 images (55%)]	Loss: 0.055815
# Train Epoch: 4 [35840/60000 images (60%)]	Loss: 0.072486
# Train Epoch: 4 [38400/60000 images (64%)]	Loss: 0.130445
# Train Epoch: 4 [40960/60000 images (68%)]	Loss: 0.128281
# Train Epoch: 4 [43520/60000 images (73%)]	Loss: 0.158996
# Train Epoch: 4 [46080/60000 images (77%)]	Loss: 0.068152
# Train Epoch: 4 [48640/60000 images (81%)]	Loss: 0.105778
# Train Epoch: 4 [51200/60000 images (85%)]	Loss: 0.181310
# Train Epoch: 4 [53760/60000 images (90%)]	Loss: 0.083144
# Train Epoch: 4 [56320/60000 images (94%)]	Loss: 0.142468
# Train Epoch: 4 [58880/60000 images (98%)]	Loss: 0.156844
#
# Test loss: 0.1404, Accuracy: 9626/10000 (96%)
#
# Train Epoch: 5 [0/60000 images (0%)]	Loss: 0.078297
# Train Epoch: 5 [2560/60000 images (4%)]	Loss: 0.041905
# Train Epoch: 5 [5120/60000 images (9%)]	Loss: 0.118658
# Train Epoch: 5 [7680/60000 images (13%)]	Loss: 0.156786
# Train Epoch: 5 [10240/60000 images (17%)]	Loss: 0.059041
# Train Epoch: 5 [12800/60000 images (21%)]	Loss: 0.077594
# Train Epoch: 5 [15360/60000 images (26%)]	Loss: 0.110020
# Train Epoch: 5 [17920/60000 images (30%)]	Loss: 0.091822
# Train Epoch: 5 [20480/60000 images (34%)]	Loss: 0.120154
# Train Epoch: 5 [23040/60000 images (38%)]	Loss: 0.105060
# Train Epoch: 5 [25600/60000 images (43%)]	Loss: 0.040844
# Train Epoch: 5 [28160/60000 images (47%)]	Loss: 0.096984
# Train Epoch: 5 [30720/60000 images (51%)]	Loss: 0.103366
# Train Epoch: 5 [33280/60000 images (55%)]	Loss: 0.107925
# Train Epoch: 5 [35840/60000 images (60%)]	Loss: 0.053071
# Train Epoch: 5 [38400/60000 images (64%)]	Loss: 0.083544
# Train Epoch: 5 [40960/60000 images (68%)]	Loss: 0.038955
# Train Epoch: 5 [43520/60000 images (73%)]	Loss: 0.064532
# Train Epoch: 5 [46080/60000 images (77%)]	Loss: 0.070029
# Train Epoch: 5 [48640/60000 images (81%)]	Loss: 0.127291
# Train Epoch: 5 [51200/60000 images (85%)]	Loss: 0.092935
# Train Epoch: 5 [53760/60000 images (90%)]	Loss: 0.113461
# Train Epoch: 5 [56320/60000 images (94%)]	Loss: 0.119880
# Train Epoch: 5 [58880/60000 images (98%)]	Loss: 0.051822
#
# Test loss: 0.1291, Accuracy: 9664/10000 (97%)
